# %%
import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize   # package for flattening json in pandas df

# %%
# 0) read the MAIN data

df = pd.read_json("sab_2020.json")
df.memory_usage().sum() / (1024**2) #converting to megabytes
# df.describe()
# len(df. columns)        # number of columns = 1
# Out:
# 0.0003509521484375

# %%
df['PatentData'][2].keys() # Pandas dataframe.keys() function to find the columns of a dataframe.
# Out:
# dict_keys(['patentCaseMetadata', 'prosecutionHistoryDataBag', 'assignmentDataBag', 'st96Version', 'ipoVersion'])

# %%
# 1) initial FLATTENING from the main "PatentData"
df_pd= df["PatentData"].apply(pd.Series)
df_pd.head()
# df1.describe()
# len(df1. columns)      # number of columns = 6
# Out:
#                                   patentCaseMetadata  \
# 0  {'applicationNumberText': {'value': '16732682'...
# 1  {'applicationNumberText': {'value': '16773809'...
# 2  {'applicationNumberText': {'value': '16777041'...
# 3  {'applicationNumberText': {'value': '16636696'...
# 4  {'applicationNumberText': {'value': '16639335'...
#
#                            prosecutionHistoryDataBag  \
# 0  {'prosecutionHistoryData': [{'eventDate': '202...
# 1  {'prosecutionHistoryData': [{'eventDate': '202...
# 2  {'prosecutionHistoryData': [{'eventDate': '202...
# 3  {'prosecutionHistoryData': [{'eventDate': '202...
# 4  {'prosecutionHistoryData': [{'eventDate': '202...
#
#                                    assignmentDataBag st96Version ipoVersion  \
# 0  {'assignmentData': [{'reelNumber': '51401', 'f...        V3_1    US_V8_0
# 1  {'assignmentData': [{'reelNumber': '52125', 'f...        V3_1    US_V8_0
# 2  {'assignmentData': [{'reelNumber': '51674', 'f...        V3_1    US_V8_0
# 3  {'assignmentData': [{'reelNumber': '51722', 'f...        V3_1    US_V8_0
# 4  {'assignmentData': [{'reelNumber': '54638', 'f...        V3_1    US_V8_0
#
#   patentTermData
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df_N = pd.json_normalize(df_pd.prosecutionHistoryDataBag)
df_N
# Out:
#                                prosecutionHistoryData
# 0   [{'eventDate': '2021-06-16', 'eventCode': 'FWD...
# 1   [{'eventDate': '2021-03-25', 'eventCode': 'ELC...
# 2   [{'eventDate': '2021-07-09', 'eventCode': 'ELC...
# 3   [{'eventDate': '2021-06-09', 'eventCode': 'ELC...
# 4   [{'eventDate': '2021-05-14', 'eventCode': 'ELC...
# 5   [{'eventDate': '2021-06-16', 'eventCode': 'EML...
# 6   [{'eventDate': '2021-07-09', 'eventCode': 'WID...
# 7   [{'eventDate': '2021-05-26', 'eventCode': 'ELC...
# 8   [{'eventDate': '2021-06-25', 'eventCode': 'EML...
# 9   [{'eventDate': '2021-06-21', 'eventCode': 'FWD...
# 10  [{'eventDate': '2021-04-29', 'eventCode': 'ELC...
# 11  [{'eventDate': '2021-06-11', 'eventCode': 'EML...
# 12  [{'eventDate': '2021-06-16', 'eventCode': 'FWD...
# 13  [{'eventDate': '2021-03-11', 'eventCode': 'EML...
# 14  [{'eventDate': '2021-03-26', 'eventCode': 'ELC...
# 15  [{'eventDate': '2021-06-16', 'eventCode': 'EML...
# 16  [{'eventDate': '2021-06-21', 'eventCode': 'ELC...
# 17  [{'eventDate': '2021-07-09', 'eventCode': 'WID...
# 18  [{'eventDate': '2021-05-23', 'eventCode': 'DOC...
# 19  [{'eventDate': '2021-05-23', 'eventCode': 'DOC...
# 20  [{'eventDate': '2021-05-16', 'eventCode': 'PST...
# 21  [{'eventDate': '2021-04-22', 'eventCode': 'N42...
# 22  [{'eventDate': '2021-02-14', 'eventCode': 'DOC...
# 23  [{'eventDate': '2021-06-20', 'eventCode': 'DOC...
# 24  [{'eventDate': '2021-03-14', 'eventCode': 'DOC...
# 25  [{'eventDate': '2021-03-24', 'eventCode': 'M84...
# 26  [{'eventDate': '2021-03-28', 'eventCode': 'DOC...
# 27  [{'eventDate': '2021-07-10', 'eventCode': 'DOC...
# 28  [{'eventDate': '2021-06-06', 'eventCode': 'DOC...
# 29  [{'eventDate': '2021-06-20', 'eventCode': 'DOC...

# %%
# NEW CODE Simpler?
A=pd.json_normalize(json.loads(df_pd.to_json(orient="records")))
A.head()
# Out:
#   st96Version ipoVersion  patentTermData  \
# 0        V3_1    US_V8_0             NaN
# 1        V3_1    US_V8_0             NaN
# 2        V3_1    US_V8_0             NaN
# 3        V3_1    US_V8_0             NaN
# 4        V3_1    US_V8_0             NaN
#
#   patentCaseMetadata.applicationNumberText.value  \
# 0                                       16732682
# 1                                       16773809
# 2                                       16777041
# 3                                       16636696
# 4                                       16639335
#
#   patentCaseMetadata.applicationNumberText.electronicText  \
# 0                                           16732682
# 1                                           16773809
# 2                                           16777041
# 3                                           16636696
# 4                                           16639335
#
#   patentCaseMetadata.filingDate patentCaseMetadata.applicationTypeCategory  \
# 0                    2020-01-02                                    Utility
# 1                    2020-01-27                                    Utility
# 2                    2020-01-30                                    Utility
# 3                    2020-02-05                                    Utility
# 4                    2020-02-14                                    Utility
#
#   patentCaseMetadata.partyBag.applicantBagOrInventorBagOrOwnerBag  \
# 0  [{'primaryExaminerOrAssistantExaminerOrAuthori...
# 1  [{'primaryExaminerOrAssistantExaminerOrAuthori...
# 2  [{'primaryExaminerOrAssistantExaminerOrAuthori...
# 3  [{'primaryExaminerOrAssistantExaminerOrAuthori...
# 4  [{'primaryExaminerOrAssistantExaminerOrAuthori...
#
#   patentCaseMetadata.groupArtUnitNumber.value  \
# 0                                        2641
# 1                                        2641
# 2                                        2641
# 3                                        2641
# 4                                        2641
#
#   patentCaseMetadata.groupArtUnitNumber.electronicText  ...  \
# 0                                               2641    ...
# 1                                               2641    ...
# 2                                               2641    ...
# 3                                               2641    ...
# 4                                               2641    ...
#
#   patentCaseMetadata.patentGrantIdentification.grantDate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   patentTermData.patentTermAdjustmentData.aDelayQuantity  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   patentTermData.patentTermAdjustmentData.bDelayQuantity  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   patentTermData.patentTermAdjustmentData.cDelayQuantity  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   patentTermData.patentTermAdjustmentData.overlappingDayQuantity  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   patentTermData.patentTermAdjustmentData.nonOverlappingDayQuantity  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   patentTermData.patentTermAdjustmentData.ipOfficeDayDelayQuantity  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   patentTermData.patentTermAdjustmentData.applicantDayDelayQuantity  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   patentTermData.patentTermAdjustmentData.adjustmentTotalQuantity  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   patentTermData.patentTermAdjustmentData.patentTermAdjustmentHistoryDataBag.patentTermAdjustmentHistoryData
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 38 columns]

# %%
df_pd['prosecutionHistoryDataBag'][0].keys()
# Out:
# dict_keys(['prosecutionHistoryData'])

# %%
df_ad= df_pd["assignmentDataBag"].apply(pd.Series)
df_ad.head()
# Out:
#     0                                     assignmentData  \
# 0 NaN  [{'reelNumber': '51401', 'frameNumber': '252',...
# 1 NaN  [{'reelNumber': '52125', 'frameNumber': '192',...
# 2 NaN  [{'reelNumber': '51674', 'frameNumber': '43', ...
# 3 NaN  [{'reelNumber': '51722', 'frameNumber': '940',...
# 4 NaN  [{'reelNumber': '54638', 'frameNumber': '405',...
#
#    assignmentTotalQuantity
# 0                      1.0
# 1                      2.0
# 2                      1.0
# 3                      1.0
# 4                      1.0

# %%
# flattening prosecution History from 'prosecutionHistoryDataBag'

df_Hist = df_pd["prosecutionHistoryDataBag"].apply(pd.Series)
df_Hist = df_Hist["prosecutionHistoryData"].apply(pd.Series)

df_Hist.head()
# dfH3 = dfH1["0"].apply(pd.Series)
# dfH3


#   Need to be able to separate "eventDate" and "eventCode" to separate columns;
# then CREATE AND COMPUTE the sequence of the event and dates !!!!
# Out:
#                                                   0   \
# 0  {'eventDate': '2021-06-16', 'eventCode': 'FWDX...
# 1  {'eventDate': '2021-03-25', 'eventCode': 'ELC_...
# 2  {'eventDate': '2021-07-09', 'eventCode': 'ELC_...
# 3  {'eventDate': '2021-06-09', 'eventCode': 'ELC_...
# 4  {'eventDate': '2021-05-14', 'eventCode': 'ELC_...
#
#                                                   1   \
# 0  {'eventDate': '2021-06-10', 'eventCode': 'A......
# 1  {'eventDate': '2021-03-25', 'eventCode': 'EML_...
# 2  {'eventDate': '2021-07-09', 'eventCode': 'EML_...
# 3  {'eventDate': '2021-06-09', 'eventCode': 'EML_...
# 4  {'eventDate': '2021-05-13', 'eventCode': 'EML_...
#
#                                                   2   \
# 0  {'eventDate': '2021-03-10', 'eventCode': 'ELC_...
# 1  {'eventDate': '2021-03-25', 'eventCode': 'MCTN...
# 2  {'eventDate': '2021-07-09', 'eventCode': 'MCTF...
# 3  {'eventDate': '2021-06-09', 'eventCode': 'MCTN...
# 4  {'eventDate': '2021-05-13', 'eventCode': 'MCTN...
#
#                                                   3   \
# 0  {'eventDate': '2021-03-10', 'eventCode': 'EML_...
# 1  {'eventDate': '2021-03-21', 'eventCode': 'CTNF...
# 2  {'eventDate': '2021-07-03', 'eventCode': 'CTFR...
# 3  {'eventDate': '2021-06-04', 'eventCode': 'CTNF...
# 4  {'eventDate': '2021-05-08', 'eventCode': 'CTNF...
#
#                                                   4   \
# 0  {'eventDate': '2021-03-10', 'eventCode': 'MCTN...
# 1  {'eventDate': '2020-07-30', 'eventCode': 'A.PE...
# 2  {'eventDate': '2021-05-20', 'eventCode': 'FWDX...
# 3  {'eventDate': '2021-06-04', 'eventCode': 'IDSC...
# 4  {'eventDate': '2021-05-08', 'eventCode': 'IDSC...
#
#                                                   5   \
# 0  {'eventDate': '2021-03-06', 'eventCode': 'CTNF...
# 1  {'eventDate': '2020-07-24', 'eventCode': 'EML_...
# 2  {'eventDate': '2021-05-18', 'eventCode': 'A......
# 3  {'eventDate': '2021-06-04', 'eventCode': 'IDSC...
# 4  {'eventDate': '2021-05-08', 'eventCode': 'IDSC...
#
#                                                   6   \
# 0  {'eventDate': '2021-03-06', 'eventCode': 'IDSC...
# 1  {'eventDate': '2020-07-23', 'eventCode': 'CCRD...
# 2  {'eventDate': '2021-05-11', 'eventCode': 'EML_...
# 3  {'eventDate': '2021-06-04', 'eventCode': 'IDSC...
# 4  {'eventDate': '2021-03-04', 'eventCode': 'M844...
#
#                                                   7   \
# 0  {'eventDate': '2020-05-01', 'eventCode': 'EML_...
# 1  {'eventDate': '2020-07-23', 'eventCode': 'PG-I...
# 2  {'eventDate': '2021-05-11', 'eventCode': 'MEXI...
# 3  {'eventDate': '2021-05-10', 'eventCode': 'LET....
# 4  {'eventDate': '2021-03-04', 'eventCode': 'WIDS...
#
#                                                   8   \
# 0  {'eventDate': '2020-04-30', 'eventCode': 'PG-I...
# 1  {'eventDate': '2020-04-17', 'eventCode': 'EML_...
# 2  {'eventDate': '2021-05-05', 'eventCode': 'EXAT...
# 3  {'eventDate': '2021-04-30', 'eventCode': 'EML_...
# 4  {'eventDate': '2021-02-05', 'eventCode': 'EML_...
#
#                                                   9   ...   56   57   58   59  \
# 0  {'eventDate': '2020-03-13', 'eventCode': 'M844...  ...  NaN  NaN  NaN  NaN
# 1  {'eventDate': '2020-04-16', 'eventCode': 'DOCK...  ...  NaN  NaN  NaN  NaN
# 2  {'eventDate': '2021-05-06', 'eventCode': 'EXIN...  ...  NaN  NaN  NaN  NaN
# 3  {'eventDate': '2021-04-29', 'eventCode': 'CCRD...  ...  NaN  NaN  NaN  NaN
# 4  {'eventDate': '2021-02-04', 'eventCode': 'CCRD...  ...  NaN  NaN  NaN  NaN
#
#     60   61   62   63   64   65
# 0  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 66 columns]

# %%
df_Hist0 = df_Hist[0].apply(pd.Series)
df_Hist0.head()

# create a for loop with index ?????
# Out:
#     eventDate eventCode        eventDescriptionText
# 0  2021-06-16      FWDX  Date Forwarded to Examiner
# 1  2021-03-25   ELC_RVW           Electronic Review
# 2  2021-07-09   ELC_RVW           Electronic Review
# 3  2021-06-09   ELC_RVW           Electronic Review
# 4  2021-05-14   ELC_RVW           Electronic Review

# %%
df_Hist1 = df_Hist[1].apply(pd.Series)
df_Hist1.head()
# Out:
#     eventDate eventCode             eventDescriptionText
# 0  2021-06-10      A...  Response after Non-Final Action
# 1  2021-03-25   EML_NTF               Email Notification
# 2  2021-07-09   EML_NTF               Email Notification
# 3  2021-06-09   EML_NTF               Email Notification
# 4  2021-05-13   EML_NTF               Email Notification

# %%
# 2) second FLATTENING from the main "PatentData" > "patentCaseMetadata"
df_meta = df_pd["patentCaseMetadata"].apply(pd.Series)
df_meta.head()
# len(df2. columns)      # number of columns = 18
# Out:
#                                applicationNumberText  filingDate  \
# 0  {'value': '16732682', 'electronicText': '16732...  2020-01-02
# 1  {'value': '16773809', 'electronicText': '16773...  2020-01-27
# 2  {'value': '16777041', 'electronicText': '16777...  2020-01-30
# 3  {'value': '16636696', 'electronicText': '16636...  2020-02-05
# 4  {'value': '16639335', 'electronicText': '16639...  2020-02-14
#
#   applicationTypeCategory                                           partyBag  \
# 0                 Utility  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 1                 Utility  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 2                 Utility  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 3                 Utility  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 4                 Utility  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
#
#                             groupArtUnitNumber applicationConfirmationNumber  \
# 0  {'value': '2641', 'electronicText': '2641'}                          3131
# 1  {'value': '2641', 'electronicText': '2641'}                          6625
# 2  {'value': '2641', 'electronicText': '2641'}                          7168
# 3  {'value': '2641', 'electronicText': '2641'}                          6113
# 4  {'value': '2641', 'electronicText': '2641'}                          9050
#
#   applicantFileReference                            patentClassificationBag  \
# 0           114281.00012  {'cpcClassificationBagOrIPCClassificationOrECL...
# 1        41FH-295289-US2  {'cpcClassificationBagOrIPCClassificationOrECL...
# 2             20180528C1  {'cpcClassificationBagOrIPCClassificationOrECL...
# 3              MYM-008US  {'cpcClassificationBagOrIPCClassificationOrECL...
# 4        NC103464-US-PCT  {'cpcClassificationBagOrIPCClassificationOrECL...
#
#   businessEntityStatusCategory firstInventorToFileIndicator  \
# 0                        SMALL                         true
# 1                        SMALL                         true
# 2                 UNDISCOUNTED                         true
# 3                 UNDISCOUNTED                         true
# 4                 UNDISCOUNTED                         true
#
#                                       inventionTitle  \
# 0  {'content': ['SYSTEM AND METHOD FOR FACILITATI...
# 1  {'content': ['COMMUNITY SAFETY, SECURITY, HEAL...
# 2  {'content': ['METHOD AND DEVICE FOR COMMUNICAT...
# 3                     {'content': ['ACCESS SYSTEM']}
# 4  {'content': ['REGISTERING USER EQUIPMENT WITH ...
#
#                            applicationStatusCategory applicationStatusDate  \
# 0  Response to Non-Final Office Action Entered an...            2021-06-16
# 1                            Non Final Action Mailed            2021-03-23
# 2                             Final Rejection Mailed            2021-07-07
# 3                            Non Final Action Mailed            2021-06-07
# 4                            Non Final Action Mailed            2021-05-11
#
#   officialFileLocationCategory  \
# 0                   ELECTRONIC
# 1                   ELECTRONIC
# 2                   ELECTRONIC
# 3                   ELECTRONIC
# 4                   ELECTRONIC
#
#                      patentPublicationIdentification  \
# 0  {'publicationNumber': 'US20200137223A1', 'publ...
# 1  {'publicationNumber': 'US20200236209A1', 'publ...
# 2  {'publicationNumber': 'US20200204964A1', 'publ...
# 3  {'publicationNumber': 'US20210127275A1', 'publ...
# 4  {'publicationNumber': 'US20210037372A1', 'publ...
#
#                                  relatedDocumentData priorityClaimBag  \
# 0  {'parentDocumentDataOrChildDocumentData': [{'d...              NaN
# 1  {'parentDocumentDataOrChildDocumentData': [{'d...              NaN
# 2  {'parentDocumentDataOrChildDocumentData': [{'d...              NaN
# 3  {'parentDocumentDataOrChildDocumentData': [{'d...              NaN
# 4  {'parentDocumentDataOrChildDocumentData': [{'d...              NaN
#
#   patentGrantIdentification
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
# to get COMPANY info
A=pd.json_normalize(json.loads(df_meta.to_json(orient="records")))
A.head()
# df_comp = df_meta["partyBag"].apply(pd.Series)
# df_comp.head()
# Out:
#    filingDate applicationTypeCategory applicationConfirmationNumber  \
# 0  2020-01-02                 Utility                          3131
# 1  2020-01-27                 Utility                          6625
# 2  2020-01-30                 Utility                          7168
# 3  2020-02-05                 Utility                          6113
# 4  2020-02-14                 Utility                          9050
#
#   applicantFileReference businessEntityStatusCategory  \
# 0           114281.00012                        SMALL
# 1        41FH-295289-US2                        SMALL
# 2             20180528C1                 UNDISCOUNTED
# 3              MYM-008US                 UNDISCOUNTED
# 4        NC103464-US-PCT                 UNDISCOUNTED
#
#   firstInventorToFileIndicator  \
# 0                         true
# 1                         true
# 2                         true
# 3                         true
# 4                         true
#
#                            applicationStatusCategory applicationStatusDate  \
# 0  Response to Non-Final Office Action Entered an...            2021-06-16
# 1                            Non Final Action Mailed            2021-03-23
# 2                             Final Rejection Mailed            2021-07-07
# 3                            Non Final Action Mailed            2021-06-07
# 4                            Non Final Action Mailed            2021-05-11
#
#   officialFileLocationCategory  priorityClaimBag  ...  \
# 0                   ELECTRONIC               NaN  ...
# 1                   ELECTRONIC               NaN  ...
# 2                   ELECTRONIC               NaN  ...
# 3                   ELECTRONIC               NaN  ...
# 4                   ELECTRONIC               NaN  ...
#
#    groupArtUnitNumber.electronicText  \
# 0                               2641
# 1                               2641
# 2                               2641
# 3                               2641
# 4                               2641
#
#   patentClassificationBag.cpcClassificationBagOrIPCClassificationOrECLAClassificationBag  \
# 0  [{'ipOfficeCode': 'US', 'mainNationalClassific...
# 1  [{'ipOfficeCode': 'US', 'mainNationalClassific...
# 2  [{'ipOfficeCode': 'US', 'mainNationalClassific...
# 3  [{'ipOfficeCode': 'US', 'mainNationalClassific...
# 4  [{'ipOfficeCode': 'US', 'mainNationalClassific...
#
#                               inventionTitle.content  \
# 0  [SYSTEM AND METHOD FOR FACILITATING COMMUNICAT...
# 1  [COMMUNITY SAFETY, SECURITY, HEALTH COMMUNICAT...
# 2  [METHOD AND DEVICE FOR COMMUNICATING MESSAGES ...
# 3                                    [ACCESS SYSTEM]
# 4  [REGISTERING USER EQUIPMENT WITH A VISITED PUB...
#
#   patentPublicationIdentification.publicationNumber  \
# 0                                   US20200137223A1
# 1                                   US20200236209A1
# 2                                   US20200204964A1
# 3                                   US20210127275A1
# 4                                   US20210037372A1
#
#   patentPublicationIdentification.publicationDate  \
# 0                                      2020-04-30
# 1                                      2020-07-23
# 2                                      2020-06-25
# 3                                      2021-04-29
# 4                                      2021-02-04
#
#   relatedDocumentData.parentDocumentDataOrChildDocumentData  \
# 0  [{'descriptionText': 'This application is a Di...
# 1  [{'descriptionText': 'This application is a Co...
# 2  [{'descriptionText': 'This application is a Co...
# 3  [{'descriptionText': 'This application is Nati...
# 4  [{'descriptionText': 'This application is Nati...
#
#   priorityClaimBag.priorityClaim patentGrantIdentification.patentNumber  \
# 0                            NaN                                    NaN
# 1                            NaN                                    NaN
# 2                            NaN                                    NaN
# 3                            NaN                                    NaN
# 4                            NaN                                    NaN
#
#   patentGrantIdentification.grantDate relatedDocumentData
# 0                                 NaN                 NaN
# 1                                 NaN                 NaN
# 2                                 NaN                 NaN
# 3                                 NaN                 NaN
# 4                                 NaN                 NaN
#
# [5 rows x 25 columns]

# %%
# to get COMPANY info
Ac = A["partyBag.applicantBagOrInventorBagOrOwnerBag"].apply(pd.Series)
Ac = Ac[1].apply(pd.Series)
Ac = Ac['applicant'].apply(pd.Series)
Ac = Ac[0].apply(pd.Series)
Ac = Ac['contactOrPublicationContact'].apply(pd.Series)
Ac = Ac[0].apply(pd.Series)
Ac = Ac['name'].apply(pd.Series)
Ac = Ac['personNameOrOrganizationNameOrEntityName'].apply(pd.Series)
Ac = Ac[0].apply(pd.Series)
Ac = Ac['organizationStandardName'].apply(pd.Series)
Ac = Ac['content'].apply(pd.Series)
Ac
# rename the column "personFullName" to "Examiner"
df_comp = Ac.rename(columns={0: 'Company'})
df_comp.head()
# A1 = A["partyBag.applicantBagOrInventorBagOrOwnerBag"].apply(pd.Series)
# A2 = A1[1].apply(pd.Series)
# A3 = A2['applicant'].apply(pd.Series)
# A4 = A3[0].apply(pd.Series)
# A5 = A4['contactOrPublicationContact'].apply(pd.Series)
# A6 = A5[0].apply(pd.Series)
# A7 = A6['name'].apply(pd.Series)
# A8 = A7['personNameOrOrganizationNameOrEntityName'].apply(pd.Series)
# A9 = A8[0].apply(pd.Series)
# A10 = A9['organizationStandardName'].apply(pd.Series)
# A11 = A10['content'].apply(pd.Series)
# A11
# Out:
#                                       Company
# 0                    INMATE TEXT SERVICE, LLC
# 1  Titan Health & Security Technologies, Inc.
# 2           Verizon Patent and Licensing Inc.
# 3                        MYOMEGA SYSTEMS GMBH
# 4                       Nokia Technologies Oy

# %%
df_c1 = df_meta["patentClassificationBag"].apply(pd.Series)
df_c2 = df_c1["cpcClassificationBagOrIPCClassificationOrECLAClassificationBag"].apply(pd.Series)
df_c3 = df_c2[0].apply(pd.Series)
df_clsf = df_c3["mainNationalClassification"].apply(pd.Series)
df_clsf
# Out:
#    nationalClass nationalSubclass
# 0            455           466000
# 1            455           404100
# 2            455           466000
# 3            455           456600
# 4            455           411000
# 5            455           456100
# 6            455           466000
# 7            455           456300
# 8            455           450000
# 9            382           103000
# 10           455           452200
# 11           455           435100
# 12           455           466000
# 13           455           456300
# 14           455           411000
# 15           455           435100
# 16           455           458000
# 17           455           410000
# 18           455           411000
# 19           455           452100
# 20           455           432100
# 21           455           434000
# 22           455           411000
# 23           455           436000
# 24           455           436000
# 25           455           435100
# 26           455           435100
# 27           455           435300
# 28           455           411000
# 29           455           466000

# %%
df_meta.memory_usage().sum() / (1024**2) #converting to megabytes
# Out:
# 0.004241943359375

# %%
df_au = df_meta["groupArtUnitNumber"].apply(pd.Series)
df_au.head()
# Out:
#   value electronicText
# 0  2641           2641
# 1  2641           2641
# 2  2641           2641
# 3  2641           2641
# 4  2641           2641

# %%
# rename the column "value" to "applicationNumber"
df_au = df_au.rename(columns={'value': 'Art Unit'})
 
# drop "applicationNumberText" from "df_meta"
df_au = df_au.drop(['electronicText'], axis=1)
df_au
# Out:
#    Art Unit
# 0      2641
# 1      2641
# 2      2641
# 3      2641
# 4      2641
# 5      2641
# 6      2641
# 7      2641
# 8      2641
# 9      2641
# 10     2641
# 11     2641
# 12     2641
# 13     2641
# 14     2641
# 15     2641
# 16     2641
# 17     2641
# 18     2641
# 19     2641
# 20     2641
# 21     2641
# 22     2641
# 23     2641
# 24     2641
# 25     2641
# 26     2641
# 27     2641
# 28     2641
# 29     2641

# %%
dfb = df_meta["partyBag"].apply(pd.Series)
dfb = dfb["applicantBagOrInventorBagOrOwnerBag"].apply(pd.Series)
dfb = dfb[0].apply(pd.Series)
dfb = dfb['primaryExaminerOrAssistantExaminerOrAuthorizedOfficer'].apply(pd.Series)
dfb = dfb[0].apply(pd.Series)
dfb = dfb['name'].apply(pd.Series)
dfb = dfb['personNameOrOrganizationNameOrEntityName'].apply(pd.Series)
dfb = dfb[0].apply(pd.Series)
dfb.head()
# Out:
#    personFullName
# 0  SABOURI, MAZDA
# 1  SABOURI, MAZDA
# 2  SABOURI, MAZDA
# 3  SABOURI, MAZDA
# 4  SABOURI, MAZDA

# %%
dfe3 = df_meta["partyBag"].apply(pd.Series)
dfe4 = dfe3["applicantBagOrInventorBagOrOwnerBag"].apply(pd.Series)
dfe5 = dfe4[0].apply(pd.Series)
dfe6 = dfe5['primaryExaminerOrAssistantExaminerOrAuthorizedOfficer'].apply(pd.Series)
dfe7 = dfe6[0].apply(pd.Series)
dfe8 = dfe7['name'].apply(pd.Series)
dfe9 = dfe8['personNameOrOrganizationNameOrEntityName'].apply(pd.Series)
dfe10 = dfe9[0].apply(pd.Series)
# df11 = df10['personFullName'].apply(pd.Series)
# df12 = df11[0].apply(pd.Series)
dfe6.head()
# Out:
#                                                    0
# 0  {'name': {'personNameOrOrganizationNameOrEntit...
# 1  {'name': {'personNameOrOrganizationNameOrEntit...
# 2  {'name': {'personNameOrOrganizationNameOrEntit...
# 3  {'name': {'personNameOrOrganizationNameOrEntit...
# 4  {'name': {'personNameOrOrganizationNameOrEntit...

# %%
# rename to EXMR

# rename the column "personFullName" to "Examiner"
df_ex = dfb.rename(columns={'personFullName': 'Examiner'})
df_ex.head()
# Out:
#          Examiner
# 0  SABOURI, MAZDA
# 1  SABOURI, MAZDA
# 2  SABOURI, MAZDA
# 3  SABOURI, MAZDA
# 4  SABOURI, MAZDA

# %%
# 3) 3rd FLATTENING from the main "PatentData" > "patentCaseMetadata" > applicationNumberText
df_appl = df_meta["applicationNumberText"].apply(pd.Series)
df_appl
# Out:
#        value electronicText
# 0   16732682       16732682
# 1   16773809       16773809
# 2   16777041       16777041
# 3   16636696       16636696
# 4   16639335       16639335
# 5   16793134       16793134
# 6   16831103       16831103
# 7   16841817       16841817
# 8   16757380       16757380
# 9   16852881       16852881
# 10  16867185       16867185
# 11  16768641       16768641
# 12  16892842       16892842
# 13  16895778       16895778
# 14  16957067       16957067
# 15  16957083       16957083
# 16  16911997       16911997
# 17  16916853       16916853
# 18  16922813       16922813
# 19  16937613       16937613
# 20  16939749       16939749
# 21  16939955       16939955
# 22  16941769       16941769
# 23  16987678       16987678
# 24  16989992       16989992
# 25  17010101       17010101
# 26  17031576       17031576
# 27  17036748       17036748
# 28  17043562       17043562
# 29  16948949       16948949

# %%
# rename the column "value" to "applicationNumber"
df_appl = df_appl.rename(columns={'value': 'applicationNumber'})
df_appl.head()
# Out:
#   applicationNumber electronicText
# 0          16732682       16732682
# 1          16773809       16773809
# 2          16777041       16777041
# 3          16636696       16636696
# 4          16639335       16639335

# %%
# drop 'electronicText' from df_appl

df_appl = df_appl.drop(['electronicText'], axis=1)
df_appl
# Out:
#    applicationNumber
# 0           16732682
# 1           16773809
# 2           16777041
# 3           16636696
# 4           16639335
# 5           16793134
# 6           16831103
# 7           16841817
# 8           16757380
# 9           16852881
# 10          16867185
# 11          16768641
# 12          16892842
# 13          16895778
# 14          16957067
# 15          16957083
# 16          16911997
# 17          16916853
# 18          16922813
# 19          16937613
# 20          16939749
# 21          16939955
# 22          16941769
# 23          16987678
# 24          16989992
# 25          17010101
# 26          17031576
# 27          17036748
# 28          17043562
# 29          16948949

# %%
# drop "applicationNumberText" from "df_meta"
df_meta = df_meta.drop(['applicationNumberText'], axis=1)
df_meta = df_meta.drop(['groupArtUnitNumber'], axis=1)
df_meta.head()
# Out:
#    filingDate applicationTypeCategory  \
# 0  2020-01-02                 Utility
# 1  2020-01-27                 Utility
# 2  2020-01-30                 Utility
# 3  2020-02-05                 Utility
# 4  2020-02-14                 Utility
#
#                                             partyBag  \
# 0  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 1  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 2  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 3  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 4  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
#
#   applicationConfirmationNumber applicantFileReference  \
# 0                          3131           114281.00012
# 1                          6625        41FH-295289-US2
# 2                          7168             20180528C1
# 3                          6113              MYM-008US
# 4                          9050        NC103464-US-PCT
#
#                              patentClassificationBag  \
# 0  {'cpcClassificationBagOrIPCClassificationOrECL...
# 1  {'cpcClassificationBagOrIPCClassificationOrECL...
# 2  {'cpcClassificationBagOrIPCClassificationOrECL...
# 3  {'cpcClassificationBagOrIPCClassificationOrECL...
# 4  {'cpcClassificationBagOrIPCClassificationOrECL...
#
#   businessEntityStatusCategory firstInventorToFileIndicator  \
# 0                        SMALL                         true
# 1                        SMALL                         true
# 2                 UNDISCOUNTED                         true
# 3                 UNDISCOUNTED                         true
# 4                 UNDISCOUNTED                         true
#
#                                       inventionTitle  \
# 0  {'content': ['SYSTEM AND METHOD FOR FACILITATI...
# 1  {'content': ['COMMUNITY SAFETY, SECURITY, HEAL...
# 2  {'content': ['METHOD AND DEVICE FOR COMMUNICAT...
# 3                     {'content': ['ACCESS SYSTEM']}
# 4  {'content': ['REGISTERING USER EQUIPMENT WITH ...
#
#                            applicationStatusCategory applicationStatusDate  \
# 0  Response to Non-Final Office Action Entered an...            2021-06-16
# 1                            Non Final Action Mailed            2021-03-23
# 2                             Final Rejection Mailed            2021-07-07
# 3                            Non Final Action Mailed            2021-06-07
# 4                            Non Final Action Mailed            2021-05-11
#
#   officialFileLocationCategory  \
# 0                   ELECTRONIC
# 1                   ELECTRONIC
# 2                   ELECTRONIC
# 3                   ELECTRONIC
# 4                   ELECTRONIC
#
#                      patentPublicationIdentification  \
# 0  {'publicationNumber': 'US20200137223A1', 'publ...
# 1  {'publicationNumber': 'US20200236209A1', 'publ...
# 2  {'publicationNumber': 'US20200204964A1', 'publ...
# 3  {'publicationNumber': 'US20210127275A1', 'publ...
# 4  {'publicationNumber': 'US20210037372A1', 'publ...
#
#                                  relatedDocumentData priorityClaimBag  \
# 0  {'parentDocumentDataOrChildDocumentData': [{'d...              NaN
# 1  {'parentDocumentDataOrChildDocumentData': [{'d...              NaN
# 2  {'parentDocumentDataOrChildDocumentData': [{'d...              NaN
# 3  {'parentDocumentDataOrChildDocumentData': [{'d...              NaN
# 4  {'parentDocumentDataOrChildDocumentData': [{'d...              NaN
#
#   patentGrantIdentification
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
# add df_appl and df_ex to df2

dfnew = pd.concat([df_clsf, df_meta], axis=1, join="inner")
dfnew = pd.concat([df_comp, dfnew], axis=1, join="inner")
dfnew = pd.concat([df_au, dfnew], axis=1, join="inner")
dfnew = pd.concat([df_ex, dfnew], axis=1, join="inner")
dfnew = pd.concat([df_appl, dfnew], axis=1, join="inner")

dfnew
# Out:
#    applicationNumber        Examiner Art Unit  \
# 0           16732682  SABOURI, MAZDA     2641
# 1           16773809  SABOURI, MAZDA     2641
# 2           16777041  SABOURI, MAZDA     2641
# 3           16636696  SABOURI, MAZDA     2641
# 4           16639335  SABOURI, MAZDA     2641
# 5           16793134  SABOURI, MAZDA     2641
# 6           16831103  SABOURI, MAZDA     2641
# 7           16841817  SABOURI, MAZDA     2641
# 8           16757380  SABOURI, MAZDA     2641
# 9           16852881  SABOURI, MAZDA     2641
# 10          16867185  SABOURI, MAZDA     2641
# 11          16768641  SABOURI, MAZDA     2641
# 12          16892842  SABOURI, MAZDA     2641
# 13          16895778  SABOURI, MAZDA     2641
# 14          16957067  SABOURI, MAZDA     2641
# 15          16957083  SABOURI, MAZDA     2641
# 16          16911997  SABOURI, MAZDA     2641
# 17          16916853  SABOURI, MAZDA     2641
# 18          16922813  SABOURI, MAZDA     2641
# 19          16937613  SABOURI, MAZDA     2641
# 20          16939749  SABOURI, MAZDA     2641
# 21          16939955  SABOURI, MAZDA     2641
# 22          16941769  SABOURI, MAZDA     2641
# 23          16987678  SABOURI, MAZDA     2641
# 24          16989992  SABOURI, MAZDA     2641
# 25          17010101  SABOURI, MAZDA     2641
# 26          17031576  SABOURI, MAZDA     2641
# 27          17036748  SABOURI, MAZDA     2641
# 28          17043562  SABOURI, MAZDA     2641
# 29          16948949  SABOURI, MAZDA     2641
#
#                                               Company nationalClass  \
# 0                            INMATE TEXT SERVICE, LLC           455
# 1          Titan Health & Security Technologies, Inc.           455
# 2                   Verizon Patent and Licensing Inc.           455
# 3                                MYOMEGA SYSTEMS GMBH           455
# 4                               Nokia Technologies Oy           455
# 5                                MyOmega Systems GmbH           455
# 6                   Verizon Patent and Licensing Inc.           455
# 7                                           Snap Inc.           455
# 8   GUANGDONG OPPO MOBILE TELECOMMUNICATIONS CORP....           455
# 9                                          Google LLC           382
# 10                                LG Electronics Inc.           455
# 11                                   Tele2 Sverige AB           455
# 12                           INMATE TEXT SERVICE, LLC           455
# 13                Advanced New Technologies Co., Ltd.           455
# 14                            Xirgo Technologies, LLC           455
# 15           Telefonaktiebolaget LM Ericsson   (publ)           455
# 16                              QUALCOMM Incorporated           455
# 17                                    NEC Corporation           455
# 18                                         Apple Inc.           455
# 19                                                NaN           455
# 20                             Cisco Technology, Inc.           455
# 21                                    ZTE Corporation           455
# 22                      HUAWEI TECHNOLOGIES CO., LTD.           455
# 23                      Samsung Electronics Co., Ltd.           455
# 24                       MediaTek Singapore Pte. Ltd.           455
# 25                      HUAWEI TECHNOLOGIES CO., LTD.           455
# 26                      HUAWEI TECHNOLOGIES CO., LTD.           455
# 27             Telefonaktiebolaget LM Ericsson (publ)           455
# 28             TELEFONAKTIEBOLAGET LM ERICSSON (PUBL)           455
# 29                              QUALCOMM Incorporated           455
#
#    nationalSubclass  filingDate applicationTypeCategory  \
# 0            466000  2020-01-02                 Utility
# 1            404100  2020-01-27                 Utility
# 2            466000  2020-01-30                 Utility
# 3            456600  2020-02-05                 Utility
# 4            411000  2020-02-14                 Utility
# 5            456100  2020-02-18                 Utility
# 6            466000  2020-03-26                 Utility
# 7            456300  2020-04-07                 Utility
# 8            450000  2020-04-18                 Utility
# 9            103000  2020-04-20                 Utility
# 10           452200  2020-05-05                 Utility
# 11           435100  2020-05-29                 Utility
# 12           466000  2020-06-04                 Utility
# 13           456300  2020-06-08                 Utility
# 14           411000  2020-06-22                 Utility
# 15           435100  2020-06-22                 Utility
# 16           458000  2020-06-25                 Utility
# 17           410000  2020-06-30                 Utility
# 18           411000  2020-07-07                 Utility
# 19           452100  2020-07-24                 Utility
# 20           432100  2020-07-27                 Utility
# 21           434000  2020-07-27                 Utility
# 22           411000  2020-07-29                 Utility
# 23           436000  2020-08-07                 Utility
# 24           436000  2020-08-11                 Utility
# 25           435100  2020-09-02                 Utility
# 26           435100  2020-09-24                 Utility
# 27           435300  2020-09-29                 Utility
# 28           411000  2020-09-29                 Utility
# 29           466000  2020-10-07                 Utility
#
#                                              partyBag  \
# 0   {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 1   {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 2   {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 3   {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 4   {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 5   {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 6   {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 7   {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 8   {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 9   {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 10  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 11  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 12  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 13  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 14  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 15  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 16  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 17  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 18  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 19  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 20  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 21  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 22  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 23  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 24  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 25  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 26  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 27  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 28  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
# 29  {'applicantBagOrInventorBagOrOwnerBag': [{'pri...
#
#    applicationConfirmationNumber  ... businessEntityStatusCategory  \
# 0                           3131  ...                        SMALL
# 1                           6625  ...                        SMALL
# 2                           7168  ...                 UNDISCOUNTED
# 3                           6113  ...                 UNDISCOUNTED
# 4                           9050  ...                 UNDISCOUNTED
# 5                           3046  ...                 UNDISCOUNTED
# 6                           9451  ...                 UNDISCOUNTED
# 7                           1624  ...                 UNDISCOUNTED
# 8                           2734  ...                 UNDISCOUNTED
# 9                           5817  ...                 UNDISCOUNTED
# 10                          9630  ...                 UNDISCOUNTED
# 11                          1010  ...                 UNDISCOUNTED
# 12                          1094  ...                        SMALL
# 13                          9048  ...                 UNDISCOUNTED
# 14                          3197  ...                        SMALL
# 15                          1208  ...                 UNDISCOUNTED
# 16                          9925  ...                 UNDISCOUNTED
# 17                          5448  ...                 UNDISCOUNTED
# 18                          9911  ...                 UNDISCOUNTED
# 19                          2015  ...                        SMALL
# 20                          5435  ...                 UNDISCOUNTED
# 21                          5273  ...                 UNDISCOUNTED
# 22                          8917  ...                 UNDISCOUNTED
# 23                          8485  ...                 UNDISCOUNTED
# 24                          5216  ...                 UNDISCOUNTED
# 25                          1076  ...                 UNDISCOUNTED
# 26                          9783  ...                 UNDISCOUNTED
# 27                          1639  ...                 UNDISCOUNTED
# 28                          5333  ...                 UNDISCOUNTED
# 29                          4503  ...                 UNDISCOUNTED
#
#    firstInventorToFileIndicator  \
# 0                          true
# 1                          true
# 2                          true
# 3                          true
# 4                          true
# 5                          true
# 6                          true
# 7                          true
# 8                          true
# 9                          true
# 10                         true
# 11                         true
# 12                         true
# 13                         true
# 14                         true
# 15                         true
# 16                         true
# 17                         true
# 18                         true
# 19                         true
# 20                         true
# 21                         true
# 22                         true
# 23                         true
# 24                         true
# 25                         true
# 26                         true
# 27                         true
# 28                         true
# 29                         true
#
#                                        inventionTitle  \
# 0   {'content': ['SYSTEM AND METHOD FOR FACILITATI...
# 1   {'content': ['COMMUNITY SAFETY, SECURITY, HEAL...
# 2   {'content': ['METHOD AND DEVICE FOR COMMUNICAT...
# 3                      {'content': ['ACCESS SYSTEM']}
# 4   {'content': ['REGISTERING USER EQUIPMENT WITH ...
# 5   {'content': ['MONITORING USER ACTIVITY WITHIN ...
# 6   {'content': ['METHOD AND DEVICE FOR COMMUNICAT...
# 7   {'content': ['GEO-LOCATION BASED EVENT GALLERY']}
# 8   {'content': ['SYSTEM INFORMATION SENDING METHO...
# 9    {'content': ['Vision-Enhanced Pose Estimation']}
# 10  {'content': ['Measurement Reporting Method of ...
# 11  {'content': ['METHODS, SUBSCRIBER IDENTITY COM...
# 12  {'content': ['SYSTEM AND METHOD FOR FACILITATI...
# 13  {'content': ['METHOD AND APPARATUS FOR VERIFYI...
# 14  {'content': ['SECURED PAIRING OF VIDEO CAPTURE...
# 15  {'content': ['DEVICE REGISTRATION IN A COMMUNI...
# 16  {'content': ['UNIFIED ACCESS CONTROL PARAMETER...
# 17  {'content': ['KEY DERIVATION METHOD, COMMUNICA...
# 18  {'content': ['Backup Cellular Connectivity for...
# 19  {'content': ['METHOD AND DEVICE IN COMMUNICATI...
# 20  {'content': ['FAST ROAMING AND UNIFORM POLICY ...
# 21  {'content': ['CELL INFORMATION ACQUISITION MET...
# 22  {'content': ['MESSAGE PROTECTION METHOD AND AP...
# 23  {'content': ['METHOD AND APPARATUS FOR PERFORM...
# 24  {'content': ['Dual-Protocol for Mobility Enhan...
# 25  {'content': ['Network Slicing-Based Communicat...
# 26  {'content': ['DATA TRANSMISSION METHOD AND DAT...
# 27  {'content': ['Coordination of Simultaneous Mul...
# 28  {'content': ['METHODS FOR SUPPORT OF USER PLAN...
# 29          {'content': ['ALWAYS-ON SHORT MESSAGES']}
#
#                             applicationStatusCategory applicationStatusDate  \
# 0   Response to Non-Final Office Action Entered an...            2021-06-16
# 1                             Non Final Action Mailed            2021-03-23
# 2                              Final Rejection Mailed            2021-07-07
# 3                             Non Final Action Mailed            2021-06-07
# 4                             Non Final Action Mailed            2021-05-11
# 5                             Non Final Action Mailed            2021-06-14
# 6                             Non Final Action Mailed            2021-07-08
# 7                             Non Final Action Mailed            2021-05-24
# 8           Docketed New Case - Ready for Examination            2021-04-11
# 9   Response to Non-Final Office Action Entered an...            2021-06-21
# 10                            Non Final Action Mailed            2021-04-27
# 11          Docketed New Case - Ready for Examination            2021-03-21
# 12  Response to Non-Final Office Action Entered an...            2021-06-16
# 13                                      Patented Case            2021-03-10
# 14  Response to Non-Final Office Action Entered an...            2021-06-21
# 15                            Non Final Action Mailed            2021-06-14
# 16                            Non Final Action Mailed            2021-06-17
# 17                            Non Final Action Mailed            2021-06-08
# 18          Docketed New Case - Ready for Examination            2020-09-25
# 19          Docketed New Case - Ready for Examination            2020-09-25
# 20                             Final Rejection Mailed            2021-05-05
# 21                                      Patented Case            2021-02-24
# 22          Docketed New Case - Ready for Examination            2020-09-24
# 23          Docketed New Case - Ready for Examination            2020-09-24
# 24          Docketed New Case - Ready for Examination            2020-09-24
# 25          Docketed New Case - Ready for Examination            2020-09-24
# 26          Docketed New Case - Ready for Examination            2021-03-28
# 27          Docketed New Case - Ready for Examination            2021-07-10
# 28          Docketed New Case - Ready for Examination            2021-06-06
# 29          Docketed New Case - Ready for Examination            2021-06-20
#
#    officialFileLocationCategory  \
# 0                    ELECTRONIC
# 1                    ELECTRONIC
# 2                    ELECTRONIC
# 3                    ELECTRONIC
# 4                    ELECTRONIC
# 5                    ELECTRONIC
# 6                    ELECTRONIC
# 7                    ELECTRONIC
# 8                    ELECTRONIC
# 9                    ELECTRONIC
# 10                   ELECTRONIC
# 11                   ELECTRONIC
# 12                   ELECTRONIC
# 13                   ELECTRONIC
# 14                   ELECTRONIC
# 15                   ELECTRONIC
# 16                   ELECTRONIC
# 17                   ELECTRONIC
# 18                   ELECTRONIC
# 19                   ELECTRONIC
# 20                   ELECTRONIC
# 21                   ELECTRONIC
# 22                   ELECTRONIC
# 23                   ELECTRONIC
# 24                   ELECTRONIC
# 25                   ELECTRONIC
# 26                   ELECTRONIC
# 27                   ELECTRONIC
# 28                   ELECTRONIC
# 29                   ELECTRONIC
#
#                       patentPublicationIdentification  \
# 0   {'publicationNumber': 'US20200137223A1', 'publ...
# 1   {'publicationNumber': 'US20200236209A1', 'publ...
# 2   {'publicationNumber': 'US20200204964A1', 'publ...
# 3   {'publicationNumber': 'US20210127275A1', 'publ...
# 4   {'publicationNumber': 'US20210037372A1', 'publ...
# 5   {'publicationNumber': 'US20200183807A1', 'publ...
# 6   {'publicationNumber': 'US20200228940A1', 'publ...
# 7   {'publicationNumber': 'US20200288270A1', 'publ...
# 8   {'publicationNumber': 'US20210195503A1', 'publ...
# 9   {'publicationNumber': 'US20200320732A1', 'publ...
# 10  {'publicationNumber': 'US20200267587A1', 'publ...
# 11  {'publicationNumber': 'US20210176620A1', 'publ...
# 12  {'publicationNumber': 'US20200314236A1', 'publ...
# 13  {'publicationNumber': 'US20200304939A1', 'publ...
# 14  {'publicationNumber': 'US20200367056A1', 'publ...
# 15  {'publicationNumber': 'US20200344711A1', 'publ...
# 16  {'publicationNumber': 'US20210022107A1', 'publ...
# 17  {'publicationNumber': 'US20200329372A1', 'publ...
# 18  {'publicationNumber': 'US20210037389A1', 'publ...
# 19  {'publicationNumber': 'US20210029685A1', 'publ...
# 20  {'publicationNumber': 'US20200359273A1', 'publ...
# 21  {'publicationNumber': 'US20200358547A1', 'publ...
# 22  {'publicationNumber': 'US20200359202A1', 'publ...
# 23  {'publicationNumber': 'US20210045023A1', 'publ...
# 24  {'publicationNumber': 'US20200374773A1', 'publ...
# 25  {'publicationNumber': 'US20200404480A1', 'publ...
# 26  {'publicationNumber': 'US20210007042A1', 'publ...
# 27  {'publicationNumber': 'US20210029661A1', 'publ...
# 28  {'publicationNumber': 'US20210127271A1', 'publ...
# 29  {'publicationNumber': 'US20210152982A1', 'publ...
#
#                                   relatedDocumentData  \
# 0   {'parentDocumentDataOrChildDocumentData': [{'d...
# 1   {'parentDocumentDataOrChildDocumentData': [{'d...
# 2   {'parentDocumentDataOrChildDocumentData': [{'d...
# 3   {'parentDocumentDataOrChildDocumentData': [{'d...
# 4   {'parentDocumentDataOrChildDocumentData': [{'d...
# 5   {'parentDocumentDataOrChildDocumentData': [{'d...
# 6   {'parentDocumentDataOrChildDocumentData': [{'d...
# 7   {'parentDocumentDataOrChildDocumentData': [{'d...
# 8   {'parentDocumentDataOrChildDocumentData': [{'d...
# 9   {'parentDocumentDataOrChildDocumentData': [{'d...
# 10  {'parentDocumentDataOrChildDocumentData': [{'d...
# 11  {'parentDocumentDataOrChildDocumentData': [{'d...
# 12  {'parentDocumentDataOrChildDocumentData': [{'d...
# 13  {'parentDocumentDataOrChildDocumentData': [{'d...
# 14  {'parentDocumentDataOrChildDocumentData': [{'d...
# 15  {'parentDocumentDataOrChildDocumentData': [{'d...
# 16  {'parentDocumentDataOrChildDocumentData': [{'d...
# 17  {'parentDocumentDataOrChildDocumentData': [{'d...
# 18  {'parentDocumentDataOrChildDocumentData': [{'d...
# 19                                                NaN
# 20  {'parentDocumentDataOrChildDocumentData': [{'d...
# 21  {'parentDocumentDataOrChildDocumentData': [{'d...
# 22  {'parentDocumentDataOrChildDocumentData': [{'d...
# 23                                                NaN
# 24  {'parentDocumentDataOrChildDocumentData': [{'d...
# 25  {'parentDocumentDataOrChildDocumentData': [{'d...
# 26  {'parentDocumentDataOrChildDocumentData': [{'d...
# 27  {'parentDocumentDataOrChildDocumentData': [{'d...
# 28  {'parentDocumentDataOrChildDocumentData': [{'d...
# 29  {'parentDocumentDataOrChildDocumentData': [{'d...
#
#                                      priorityClaimBag  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'priorityClaim': [{'ipOfficeName': 'SWEDEN', ...
# 12                                                NaN
# 13  {'priorityClaim': [{'ipOfficeName': 'CHINA', '...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  {'priorityClaim': [{'ipOfficeName': 'JAPAN', '...
# 18                                                NaN
# 19  {'priorityClaim': [{'ipOfficeName': 'CHINA', '...
# 20                                                NaN
# 21                                                NaN
# 22  {'priorityClaim': [{'ipOfficeName': 'CHINA', '...
# 23  {'priorityClaim': [{'ipOfficeName': 'REPUBLIC ...
# 24  {'priorityClaim': [{'ipOfficeName': 'CHINA', '...
# 25  {'priorityClaim': [{'ipOfficeName': 'CHINA', '...
# 26  {'priorityClaim': [{'ipOfficeName': 'CHINA', '...
# 27                                                NaN
# 28  {'priorityClaim': [{'ipOfficeName': 'CHINA', '...
# 29                                                NaN
#
#                             patentGrantIdentification
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  {'patentNumber': '10966052', 'grantDate': '202...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  {'patentNumber': '10951341', 'grantDate': '202...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 22 columns]

# %%
df_comp.groupby('Company').count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Advanced New Technologies Co., Ltd., Apple Inc., Cisco Technology, Inc., GUANGDONG OPPO MOBILE TELECOMMUNICATIONS CORP., LT, Google LLC, HUAWEI TECHNOLOGIES CO., LTD., INMATE TEXT SERVICE, LLC, LG Electronics Inc., MYOMEGA SYSTEMS GMBH, MediaTek Singapore Pte. Ltd., MyOmega Systems GmbH, NEC Corporation, Nokia Technologies Oy, QUALCOMM Incorporated, Samsung Electronics Co., Ltd., Snap Inc., TELEFONAKTIEBOLAGET LM ERICSSON (PUBL), Tele2 Sverige AB, Telefonaktiebolaget LM Ericsson   (publ), Telefonaktiebolaget LM Ericsson (publ), Titan Health & Security Technologies, Inc., Verizon Patent and Licensing Inc., Xirgo Technologies, LLC, ZTE Corporation]

# %% [markdown]
# ## Count the number of applications by "Company"

# %%
dfnew['Company'].value_counts()
# Out:
# HUAWEI TECHNOLOGIES CO., LTD.                         3
# INMATE TEXT SERVICE, LLC                              2
# Verizon Patent and Licensing Inc.                     2
# QUALCOMM Incorporated                                 2
# Telefonaktiebolaget LM Ericsson   (publ)              1
# Telefonaktiebolaget LM Ericsson (publ)                1
# MediaTek Singapore Pte. Ltd.                          1
# Samsung Electronics Co., Ltd.                         1
# ZTE Corporation                                       1
# Cisco Technology, Inc.                                1
# Apple Inc.                                            1
# NEC Corporation                                       1
# Xirgo Technologies, LLC                               1
# Titan Health & Security Technologies, Inc.            1
# Advanced New Technologies Co., Ltd.                   1
# Tele2 Sverige AB                                      1
# LG Electronics Inc.                                   1
# Google LLC                                            1
# GUANGDONG OPPO MOBILE TELECOMMUNICATIONS CORP., LT    1
# Snap Inc.                                             1
# MyOmega Systems GmbH                                  1
# Nokia Technologies Oy                                 1
# MYOMEGA SYSTEMS GMBH                                  1
# TELEFONAKTIEBOLAGET LM ERICSSON (PUBL)                1
# Name: Company, dtype: int64
